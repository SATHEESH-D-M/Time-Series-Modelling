# %%
# connect to mlflow server
import mlflow

mlflow.set_tracking_uri("http://0.0.0.0:5001")

mlflow.set_experiment("NTPC-rnn-Model")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/635037021632314375', creation_time=1744445766114, experiment_id='635037021632314375', last_update_time=1744445766114, lifecycle_stage='active', name='NTPC-rnn-Model', tags={}>

# %%
# Set up logging to a file
import logging
import os

# Get current working directory
log_file_path = os.path.join(os.getcwd(), 'mlflow_run.log')

# Set up the logger manually
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# Remove all previous handlers (important in Jupyter)
logger.handlers.clear()

# Create and add FileHandler
file_handler = logging.FileHandler(log_file_path, mode='w')
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# Optional: also log to console
console_handler = logging.StreamHandler()
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import random

def set_seed(seed=42):
    """
    Set the seed for reproducibility in PyTorch, NumPy, and Python's random module.
    Ensures deterministic behavior on CPU, CUDA, and MPS.
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)  # Works for CPU & MPS

    if torch.backends.mps.is_available():
        logging.info("MPS backend is available. It uses the global PyTorch seed.")

    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)  # Multi-GPU
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

    torch.use_deterministic_algorithms(True, warn_only=True)
    logging.info("Deterministic algorithms set to True.")
    logging.info("Random seed set to: %d", seed)

# Example usage
global_seed = 42
set_seed(global_seed)
# Out:
# 2025-04-12 15:27:09,751 - INFO - MPS backend is available. It uses the global PyTorch seed.
# 2025-04-12 15:27:09,751 - INFO - Deterministic algorithms set to True.
# 2025-04-12 15:27:09,751 - INFO - Random seed set to: 42

# %%
from sklearn.preprocessing import MinMaxScaler

# Parameters
train_size = 0.9
test_size = 0.1
assert train_size + test_size == 1, "Train and test sizes must sum to 1"

# Load dataset
data = pd.read_csv('../../Data/processed_data/NTPC.csv')
logger.info(f"Loaded data shape: {data.shape}")

# Initialize scaler for normalization
scaler = MinMaxScaler(feature_range=(0, 1))

# Dataset splitting
split_index = int(len(data) * train_size)
train_data = data.iloc[:split_index]
test_data = data.iloc[split_index:]

# Reset indices
train_data = train_data.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)

# Normalize the "Close" column in both train and test sets
target_column = 'Close'
train_data[target_column] = scaler.fit_transform(train_data[[target_column]])
test_data[target_column] = scaler.transform(test_data[[target_column]])

logger.info(f"Train data shape: {train_data.shape}")
logger.info(f"Test data shape: {test_data.shape}")
# Out:
# 2025-04-12 15:27:10,204 - INFO - Loaded data shape: (4088, 13)
# 2025-04-12 15:27:10,207 - INFO - Train data shape: (3679, 13)
# 2025-04-12 15:27:10,208 - INFO - Test data shape: (409, 13)

# %%
from torch.utils.data import Dataset, DataLoader

SEQ_LENGTH = 30   # number of time steps per input sequence
BATCH_SIZE = 64
HIDDEN_SIZE = 64
NUM_LAYERS = 2
INPUT_SIZE = 1

def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:i+seq_length]
        y = data[i+seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

target_column = 'Close'
train_seq, train_target = create_sequences(train_data[target_column].values, SEQ_LENGTH)
test_seq, test_target = create_sequences(test_data[target_column].values, SEQ_LENGTH)

class TimeSeriesDataset(Dataset):
    def __init__(self, sequences, targets):
        self.x = torch.tensor(sequences, dtype=torch.float32).unsqueeze(-1)
        self.y = torch.tensor(targets, dtype=torch.float32)

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

train_dataset = TimeSeriesDataset(train_seq, train_target)
test_dataset = TimeSeriesDataset(test_seq, test_target)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
from torch import nn
class RNNModel(nn.Module):
    def __init__(self, input_size=INPUT_SIZE, hidden_size=HIDDEN_SIZE, num_layers=NUM_LAYERS):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.rnn(x)
        return self.fc(out[:, -1, :])  # Only last time step

# %%
def train(model, train_loader, criterion, optimizer, device, epoch):
    model.train()
    epoch_loss = 0

    for sequences, targets in train_loader:
        sequences, targets = sequences.to(device), targets.to(device).unsqueeze(1)

        optimizer.zero_grad()
        outputs = model(sequences)
        loss = criterion(outputs, targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        epoch_loss += loss.item()

    avg_loss = epoch_loss / len(train_loader)
    mlflow.log_metric("train_loss", avg_loss, step=epoch+1)
    logging.info(f"Epoch {epoch+1}: Train Loss = {avg_loss:.4f}")


from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / np.clip(np.abs(y_true), 1e-8, None))) * 100

def validate(model, val_loader, criterion, device, epoch, scaler):
    model.eval()
    all_preds = []
    all_targets = []
    total_loss = 0.0

    with torch.no_grad():
        for sequences, targets in val_loader:
            sequences, targets = sequences.to(device), targets.to(device).unsqueeze(1)
            outputs = model(sequences)
            loss = criterion(outputs, targets)
            total_loss += loss.item()
            all_preds.extend(outputs.cpu().numpy())
            all_targets.extend(targets.cpu().numpy())

    # Convert to numpy arrays and inverse transform
    y_true_normalized = np.array(all_targets).reshape(-1, 1)
    y_pred_normalized = np.array(all_preds).reshape(-1, 1)
    
    # Inverse transform to original scale
    y_true = scaler.inverse_transform(y_true_normalized).flatten()
    y_pred = scaler.inverse_transform(y_pred_normalized).flatten()

    # Calculate metrics on original scale
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    mape = mean_absolute_percentage_error(y_true, y_pred)

    # Logging
    logging.info(f"Epoch {epoch+1} - Val MSE: {mse:.6f}, RMSE: {rmse:.6f}, MAE: {mae:.6f}, R²: {r2:.6f}, MAPE: {mape:.6f}%")
    mlflow.log_metric("val_MSE", mse, step=epoch+1)
    mlflow.log_metric("val_RMSE", rmse, step=epoch+1)
    mlflow.log_metric("val_MAE", mae, step=epoch+1)
    mlflow.log_metric("val_R2", r2, step=epoch+1)
    mlflow.log_metric("val_MAPE", mape, step=epoch+1)

    return rmse  # Returns RMSE on original scale

# %%
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.0, verbose=False):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.verbose = verbose
        self.best_model_state = None

    def __call__(self, val_loss, model):
        if self.best_score is None or val_loss < self.best_score - self.min_delta:
            self.best_score = val_loss
            self.counter = 0
            self.best_model_state = model.state_dict()
            if self.verbose:
                logging.info(f"Monitored metric improved to {val_loss:.6f}")
        else:
            self.counter += 1
            if self.verbose:
                logging.info(f"Monitored metric did not improve. Counter: {self.counter}/{self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
                if self.verbose:
                    logging.warning("Early stopping triggered.")

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
# Initialize model
model = RNNModel(input_size=1, hidden_size=HIDDEN_SIZE, num_layers=NUM_LAYERS)


criterion_train = nn.MSELoss()
criterion_val = nn.MSELoss()


# Initialize optimizer
starting_lr = 0.001
optimizer = optim.Adam(model.parameters(), lr=starting_lr)


# Initialize learning rate scheduler
scheduler_mode = 'min'
scheduler_factor = 0.25
scheduler_patience = 2
scheduler_cooldown = 0
scheduler_min_lr = 1e-6
scheduler_threshold = 0.0001
scheduler_threshold_mode = 'abs'

scheduler = ReduceLROnPlateau(optimizer, mode=scheduler_mode,
                              factor=scheduler_factor,
                              patience=scheduler_patience,
                              cooldown=scheduler_cooldown,
                              min_lr=scheduler_min_lr,
                              threshold=scheduler_threshold,
                              threshold_mode=scheduler_threshold_mode,
                              verbose=True)

# Initialize early stopping
early_stopping_patience = scheduler_cooldown + scheduler_patience + 4
early_stopping_delta = scheduler_threshold/2
early_stopping = EarlyStopping(patience=early_stopping_patience,
                               verbose=True,
                               min_delta=early_stopping_delta)  # noqa: E501

max_num_epochs = 300

# Check device
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.backends.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
logging.info(f"Using device: {device.type}")
# Move model to device
model.to(device)


# Log params as a dictionary
params = {
    "global_seed": global_seed,
    "train_batch_size": train_size,
    "eval_batch_size": test_size,
    "loss_function": "MSELoss",
    "model_SEQ_LENGTH": SEQ_LENGTH,
    "model_HIDDEN_SIZE": HIDDEN_SIZE,
    "model_BATCH_SIZE": BATCH_SIZE,
    "model_NUM_LAYERS": NUM_LAYERS,
    "learning_rate": starting_lr,
    "optimizer": "Adam",
    "scheduler_mode": scheduler_mode,
    "scheduler_factor": scheduler_factor,
    "scheduler_patience": scheduler_patience,
    "scheduler_cooldown": scheduler_cooldown,
    "scheduler_min_lr": scheduler_min_lr,
    "scheduler_therhold": scheduler_threshold,
    "scheduler_threshold_mode": scheduler_threshold_mode,
    "scheduler": "ReduceLROnPlateau",
    "early_stopping_patience": early_stopping_patience,
    "early_stopping_delta": early_stopping_delta,
    "max_epochs": max_num_epochs,
    "device": device.type,
}
# Out:
# /opt/miniconda3/envs/MCV/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 2025-04-12 15:27:11,048 - INFO - Using device: mps

# %%
from torchinfo import summary

# Start MLflow run
with mlflow.start_run() as run:
    run_id = run.info.run_id
    logging.info(f"Started MLflow run with ID: {run_id}")

    ###########################
    # Log the model parameters
    ###########################
    try:
        mlflow.log_params(params)
        logging.info("Logged params to MLflow")
    except Exception as e:
        logging.error(f"Failed to log parameters: {e}")

    ###########################
    # Save model summary
    ###########################
    try:
        model_summary = summary(model, input_size=(SEQ_LENGTH, INPUT_SIZE), device=device.type)


        with open("model_report.txt", "w") as f:
            f.write("### MODEL ARCHITECTURE ###\n")
            f.write(str(model))
            f.write("\n\n### MODEL SUMMARY ###\n")
            f.write(str(model_summary))

        mlflow.log_artifact("model_report.txt")
        logging.info("Model report logged to MLflow")
        os.remove("model_report.txt")
    except Exception as e:
        logging.error(f"Failed to log model report: {e}")

    logging.info("Starting training...")

    ###########################
    # Training loop
    ###########################
    best_metric = float('inf')
    best_save_epoch = 0

    for epoch in range(max_num_epochs):
        try:
            current_lr = optimizer.param_groups[0]['lr']
            logging.info(f"Epoch {epoch + 1}, LR: {current_lr}")
            mlflow.log_metric("learning_rate", current_lr, step=epoch + 1)

            train(model, train_loader, criterion_train, optimizer, device, epoch)
            rmse = validate(model, test_loader, criterion_val, device, epoch, scaler)

            scheduler.step(rmse)

            # Save best model
            if rmse < best_metric:
                best_metric = rmse
                best_save_epoch = epoch
                mlflow.pytorch.log_model(model, artifact_path="best_model")
                logging.info(f"Improved RMSE: {rmse:.6f}. Logged best model to MLflow.")

            # Log latest model
            mlflow.pytorch.log_model(model, artifact_path="latest_model")

            # Early stopping
            early_stopping(rmse, model)

            if early_stopping.early_stop:
                mlflow.log_param("best_model_saved_at", best_save_epoch)
                mlflow.log_param("early_stopping_triggered_at", epoch)
                logging.warning("Early stopping triggered. Stopping training.")
                break

        except Exception as e:
            logging.error(f"Training loop failed at epoch {epoch}: {e}")
            break
        
    #########################################################
    # log the mlflow_run.log file
    #########################################################
    try:
        # Flush and close all handlers before logging the file
        for handler in logger.handlers:
            handler.flush()
            handler.close()

        mlflow.log_artifact("mlflow_run.log")
        logging.info("Logged mlflow_run.log to MLflow")

        # Now it's safe to remove the log file
        os.remove("mlflow_run.log")

        # Clear logger handlers
        logger.handlers.clear()
    except Exception as e:
        print(f"Failed to log mlflow_run.log to MLflow: {e}")
# Out:
# 2025-04-12 15:27:11,165 - INFO - Started MLflow run with ID: 8917a4866de84e728f325371df570b8e
# 2025-04-12 15:27:11,174 - INFO - Logged params to MLflow
# 2025-04-12 15:27:11,266 - ERROR - Failed to log model report: Failed to run torchinfo. See above stack traces for more details. Executed layers up to: [RNN: 1]
# 2025-04-12 15:27:11,267 - INFO - Starting training...
# 2025-04-12 15:27:11,267 - INFO - Epoch 1, LR: 0.001
# 2025-04-12 15:27:14,611 - INFO - Epoch 1: Train Loss = 0.0270
# 2025-04-12 15:27:14,759 - INFO - Epoch 1 - Val MSE: 321.659180, RMSE: 17.934859, MAE: 16.882069, R²: -1.425475, MAPE: 17.474014%
# 2025/04/12 15:27:19 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:27:19,598 - INFO - Improved RMSE: 17.934859. Logged best model to MLflow.
# 2025/04/12 15:27:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:27:23,076 - INFO - Monitored metric improved to 17.934859
# 2025-04-12 15:27:23,077 - INFO - Epoch 2, LR: 0.001
# 2025-04-12 15:27:26,101 - INFO - Epoch 2: Train Loss = 0.0007
# 2025-04-12 15:27:26,194 - INFO - Epoch 2 - Val MSE: 11.286491, RMSE: 3.359537, MAE: 2.464543, R²: 0.914894, MAPE: 2.538665%
# 2025/04/12 15:27:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:27:29,694 - INFO - Improved RMSE: 3.359537. Logged best model to MLflow.
# 2025/04/12 15:27:33 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:27:33,036 - INFO - Monitored metric improved to 3.359537
# 2025-04-12 15:27:33,036 - INFO - Epoch 3, LR: 0.001
# 2025-04-12 15:27:35,955 - INFO - Epoch 3: Train Loss = 0.0005
# 2025-04-12 15:27:36,040 - INFO - Epoch 3 - Val MSE: 36.132908, RMSE: 6.011065, MAE: 5.268382, R²: 0.727539, MAPE: 5.373787%
# 2025/04/12 15:27:39 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:27:39,378 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:27:39,379 - INFO - Epoch 4, LR: 0.001
# 2025-04-12 15:27:42,345 - INFO - Epoch 4: Train Loss = 0.0005
# 2025-04-12 15:27:42,433 - INFO - Epoch 4 - Val MSE: 18.793318, RMSE: 4.335126, MAE: 3.584411, R²: 0.858289, MAPE: 3.668150%
# 2025/04/12 15:27:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:27:45,871 - INFO - Monitored metric did not improve. Counter: 2/6
# 2025-04-12 15:27:45,872 - INFO - Epoch 5, LR: 0.001
# 2025-04-12 15:27:48,805 - INFO - Epoch 5: Train Loss = 0.0005
# 2025-04-12 15:27:48,893 - INFO - Epoch 5 - Val MSE: 17.341084, RMSE: 4.164263, MAE: 3.437049, R²: 0.869239, MAPE: 3.504774%
# 2025/04/12 15:27:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:27:52,268 - INFO - Monitored metric did not improve. Counter: 3/6
# 2025-04-12 15:27:52,268 - INFO - Epoch 6, LR: 0.00025
# 2025-04-12 15:27:55,203 - INFO - Epoch 6: Train Loss = 0.0004
# 2025-04-12 15:27:55,292 - INFO - Epoch 6 - Val MSE: 9.047384, RMSE: 3.007887, MAE: 2.278832, R²: 0.931778, MAPE: 2.343344%
# 2025/04/12 15:27:58 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:27:58,692 - INFO - Improved RMSE: 3.007887. Logged best model to MLflow.
# 2025/04/12 15:28:02 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:28:02,187 - INFO - Monitored metric improved to 3.007887
# 2025-04-12 15:28:02,187 - INFO - Epoch 7, LR: 0.00025
# 2025-04-12 15:28:05,198 - INFO - Epoch 7: Train Loss = 0.0004
# 2025-04-12 15:28:05,289 - INFO - Epoch 7 - Val MSE: 8.901205, RMSE: 2.983489, MAE: 2.247854, R²: 0.932880, MAPE: 2.308877%
# 2025/04/12 15:28:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:28:08,661 - INFO - Improved RMSE: 2.983489. Logged best model to MLflow.
# 2025/04/12 15:28:11 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:28:11,969 - INFO - Monitored metric improved to 2.983489
# 2025-04-12 15:28:11,970 - INFO - Epoch 8, LR: 0.00025
# 2025-04-12 15:28:14,926 - INFO - Epoch 8: Train Loss = 0.0004
# 2025-04-12 15:28:15,019 - INFO - Epoch 8 - Val MSE: 10.111553, RMSE: 3.179867, MAE: 2.389978, R²: 0.923754, MAPE: 2.457245%
# 2025/04/12 15:28:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:28:18,496 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:28:18,496 - INFO - Epoch 9, LR: 0.00025
# 2025-04-12 15:28:21,422 - INFO - Epoch 9: Train Loss = 0.0004
# 2025-04-12 15:28:21,510 - INFO - Epoch 9 - Val MSE: 9.862674, RMSE: 3.140489, MAE: 2.452047, R²: 0.925630, MAPE: 2.514762%
# 2025/04/12 15:28:24 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:28:24,948 - INFO - Monitored metric did not improve. Counter: 2/6
# 2025-04-12 15:28:24,949 - INFO - Epoch 10, LR: 0.00025
# 2025-04-12 15:28:27,914 - INFO - Epoch 10: Train Loss = 0.0004
# 2025-04-12 15:28:28,000 - INFO - Epoch 10 - Val MSE: 9.998604, RMSE: 3.162057, MAE: 2.422797, R²: 0.924605, MAPE: 2.472790%
# 2025/04/12 15:28:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:28:31,411 - INFO - Monitored metric did not improve. Counter: 3/6
# 2025-04-12 15:28:31,411 - INFO - Epoch 11, LR: 6.25e-05
# 2025-04-12 15:28:34,416 - INFO - Epoch 11: Train Loss = 0.0004
# 2025-04-12 15:28:34,504 - INFO - Epoch 11 - Val MSE: 8.591343, RMSE: 2.931099, MAE: 2.188933, R²: 0.935217, MAPE: 2.250233%
# 2025/04/12 15:28:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:28:38,020 - INFO - Improved RMSE: 2.931099. Logged best model to MLflow.
# 2025/04/12 15:28:41 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:28:41,405 - INFO - Monitored metric improved to 2.931099
# 2025-04-12 15:28:41,406 - INFO - Epoch 12, LR: 6.25e-05
# 2025-04-12 15:28:44,352 - INFO - Epoch 12: Train Loss = 0.0004
# 2025-04-12 15:28:44,443 - INFO - Epoch 12 - Val MSE: 8.478677, RMSE: 2.911817, MAE: 2.176637, R²: 0.936066, MAPE: 2.237316%
# 2025/04/12 15:28:47 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:28:47,882 - INFO - Improved RMSE: 2.911817. Logged best model to MLflow.
# 2025/04/12 15:28:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:28:51,228 - INFO - Monitored metric improved to 2.911817
# 2025-04-12 15:28:51,229 - INFO - Epoch 13, LR: 6.25e-05
# 2025-04-12 15:28:54,213 - INFO - Epoch 13: Train Loss = 0.0004
# 2025-04-12 15:28:54,301 - INFO - Epoch 13 - Val MSE: 8.208493, RMSE: 2.865047, MAE: 2.168925, R²: 0.938104, MAPE: 2.227584%
# 2025/04/12 15:28:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:28:57,758 - INFO - Improved RMSE: 2.865047. Logged best model to MLflow.
# 2025/04/12 15:29:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:29:01,269 - INFO - Monitored metric improved to 2.865047
# 2025-04-12 15:29:01,269 - INFO - Epoch 14, LR: 6.25e-05
# 2025-04-12 15:29:04,291 - INFO - Epoch 14: Train Loss = 0.0004
# 2025-04-12 15:29:04,381 - INFO - Epoch 14 - Val MSE: 8.441854, RMSE: 2.905487, MAE: 2.177426, R²: 0.936344, MAPE: 2.237342%
# 2025/04/12 15:29:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:29:07,861 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:29:07,861 - INFO - Epoch 15, LR: 6.25e-05
# 2025-04-12 15:29:10,870 - INFO - Epoch 15: Train Loss = 0.0004
# 2025-04-12 15:29:10,960 - INFO - Epoch 15 - Val MSE: 8.250550, RMSE: 2.872377, MAE: 2.186949, R²: 0.937787, MAPE: 2.245400%
# 2025/04/12 15:29:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:29:14,377 - INFO - Monitored metric did not improve. Counter: 2/6
# 2025-04-12 15:29:14,378 - INFO - Epoch 16, LR: 6.25e-05
# 2025-04-12 15:29:17,488 - INFO - Epoch 16: Train Loss = 0.0004
# 2025-04-12 15:29:17,579 - INFO - Epoch 16 - Val MSE: 8.191843, RMSE: 2.862140, MAE: 2.138830, R²: 0.938229, MAPE: 2.197569%
# 2025/04/12 15:29:21 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:29:21,025 - INFO - Improved RMSE: 2.862140. Logged best model to MLflow.
# 2025/04/12 15:29:24 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:29:24,477 - INFO - Monitored metric improved to 2.862140
# 2025-04-12 15:29:24,477 - INFO - Epoch 17, LR: 6.25e-05
# 2025-04-12 15:29:27,484 - INFO - Epoch 17: Train Loss = 0.0004
# 2025-04-12 15:29:27,574 - INFO - Epoch 17 - Val MSE: 8.036594, RMSE: 2.834889, MAE: 2.136608, R²: 0.939400, MAPE: 2.194346%
# 2025/04/12 15:29:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:29:31,238 - INFO - Improved RMSE: 2.834889. Logged best model to MLflow.
# 2025/04/12 15:29:34 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:29:34,593 - INFO - Monitored metric improved to 2.834889
# 2025-04-12 15:29:34,594 - INFO - Epoch 18, LR: 6.25e-05
# 2025-04-12 15:29:37,559 - INFO - Epoch 18: Train Loss = 0.0004
# 2025-04-12 15:29:37,647 - INFO - Epoch 18 - Val MSE: 7.898059, RMSE: 2.810349, MAE: 2.109242, R²: 0.940445, MAPE: 2.167174%
# 2025/04/12 15:29:41 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:29:41,075 - INFO - Improved RMSE: 2.810349. Logged best model to MLflow.
# 2025/04/12 15:29:44 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:29:44,399 - INFO - Monitored metric improved to 2.810349
# 2025-04-12 15:29:44,399 - INFO - Epoch 19, LR: 6.25e-05
# 2025-04-12 15:29:47,341 - INFO - Epoch 19: Train Loss = 0.0004
# 2025-04-12 15:29:47,426 - INFO - Epoch 19 - Val MSE: 7.922618, RMSE: 2.814715, MAE: 2.110540, R²: 0.940259, MAPE: 2.168253%
# 2025/04/12 15:29:50 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:29:50,947 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:29:50,948 - INFO - Epoch 20, LR: 6.25e-05
# 2025-04-12 15:29:53,903 - INFO - Epoch 20: Train Loss = 0.0004
# 2025-04-12 15:29:53,992 - INFO - Epoch 20 - Val MSE: 8.276712, RMSE: 2.876928, MAE: 2.208650, R²: 0.937589, MAPE: 2.266006%
# 2025/04/12 15:29:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:29:57,352 - INFO - Monitored metric did not improve. Counter: 2/6
# 2025-04-12 15:29:57,353 - INFO - Epoch 21, LR: 6.25e-05
# 2025-04-12 15:30:00,315 - INFO - Epoch 21: Train Loss = 0.0004
# 2025-04-12 15:30:00,404 - INFO - Epoch 21 - Val MSE: 7.846833, RMSE: 2.801220, MAE: 2.101303, R²: 0.940831, MAPE: 2.158364%
# 2025/04/12 15:30:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:30:03,822 - INFO - Improved RMSE: 2.801220. Logged best model to MLflow.
# 2025/04/12 15:30:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:30:07,205 - INFO - Monitored metric improved to 2.801220
# 2025-04-12 15:30:07,205 - INFO - Epoch 22, LR: 6.25e-05
# 2025-04-12 15:30:10,151 - INFO - Epoch 22: Train Loss = 0.0004
# 2025-04-12 15:30:10,240 - INFO - Epoch 22 - Val MSE: 7.922386, RMSE: 2.814673, MAE: 2.142779, R²: 0.940261, MAPE: 2.198813%
# 2025/04/12 15:30:13 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:30:13,593 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:30:13,593 - INFO - Epoch 23, LR: 6.25e-05
# 2025-04-12 15:30:16,544 - INFO - Epoch 23: Train Loss = 0.0004
# 2025-04-12 15:30:16,630 - INFO - Epoch 23 - Val MSE: 8.726286, RMSE: 2.954029, MAE: 2.220719, R²: 0.934199, MAPE: 2.281344%
# 2025/04/12 15:30:20 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:30:20,099 - INFO - Monitored metric did not improve. Counter: 2/6
# 2025-04-12 15:30:20,099 - INFO - Epoch 24, LR: 6.25e-05
# 2025-04-12 15:30:23,105 - INFO - Epoch 24: Train Loss = 0.0004
# 2025-04-12 15:30:23,194 - INFO - Epoch 24 - Val MSE: 8.195610, RMSE: 2.862798, MAE: 2.146385, R²: 0.938201, MAPE: 2.205540%
# 2025/04/12 15:30:26 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:30:26,570 - INFO - Monitored metric did not improve. Counter: 3/6
# 2025-04-12 15:30:26,570 - INFO - Epoch 25, LR: 1.5625e-05
# 2025-04-12 15:30:29,523 - INFO - Epoch 25: Train Loss = 0.0004
# 2025-04-12 15:30:29,610 - INFO - Epoch 25 - Val MSE: 7.659492, RMSE: 2.767579, MAE: 2.079288, R²: 0.942244, MAPE: 2.134999%
# 2025/04/12 15:30:33 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:30:33,352 - INFO - Improved RMSE: 2.767579. Logged best model to MLflow.
# 2025/04/12 15:30:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:30:36,713 - INFO - Monitored metric improved to 2.767579
# 2025-04-12 15:30:36,713 - INFO - Epoch 26, LR: 1.5625e-05
# 2025-04-12 15:30:39,661 - INFO - Epoch 26: Train Loss = 0.0004
# 2025-04-12 15:30:39,748 - INFO - Epoch 26 - Val MSE: 7.774114, RMSE: 2.788210, MAE: 2.086538, R²: 0.941379, MAPE: 2.142506%
# 2025/04/12 15:30:43 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:30:43,132 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:30:43,132 - INFO - Epoch 27, LR: 1.5625e-05
# 2025-04-12 15:30:46,075 - INFO - Epoch 27: Train Loss = 0.0004
# 2025-04-12 15:30:46,161 - INFO - Epoch 27 - Val MSE: 7.637797, RMSE: 2.763656, MAE: 2.088003, R²: 0.942407, MAPE: 2.143398%
# 2025/04/12 15:30:49 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:30:49,568 - INFO - Improved RMSE: 2.763656. Logged best model to MLflow.
# 2025/04/12 15:30:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:30:52,929 - INFO - Monitored metric improved to 2.763656
# 2025-04-12 15:30:52,930 - INFO - Epoch 28, LR: 1.5625e-05
# 2025-04-12 15:30:55,859 - INFO - Epoch 28: Train Loss = 0.0004
# 2025-04-12 15:30:55,944 - INFO - Epoch 28 - Val MSE: 7.651707, RMSE: 2.766172, MAE: 2.077212, R²: 0.942302, MAPE: 2.132730%
# 2025/04/12 15:30:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:30:59,296 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:30:59,296 - INFO - Epoch 29, LR: 1.5625e-05
# 2025-04-12 15:31:02,249 - INFO - Epoch 29: Train Loss = 0.0004
# 2025-04-12 15:31:02,338 - INFO - Epoch 29 - Val MSE: 7.662766, RMSE: 2.768170, MAE: 2.074285, R²: 0.942219, MAPE: 2.129815%
# 2025/04/12 15:31:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:31:05,742 - INFO - Monitored metric did not improve. Counter: 2/6
# 2025-04-12 15:31:05,742 - INFO - Epoch 30, LR: 1.5625e-05
# 2025-04-12 15:31:08,688 - INFO - Epoch 30: Train Loss = 0.0004
# 2025-04-12 15:31:08,775 - INFO - Epoch 30 - Val MSE: 7.635566, RMSE: 2.763253, MAE: 2.070097, R²: 0.942424, MAPE: 2.125455%
# 2025/04/12 15:31:12 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:31:12,104 - INFO - Improved RMSE: 2.763253. Logged best model to MLflow.
# 2025/04/12 15:31:15 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:31:15,444 - INFO - Monitored metric improved to 2.763253
# 2025-04-12 15:31:15,445 - INFO - Epoch 31, LR: 1.5625e-05
# 2025-04-12 15:31:18,570 - INFO - Epoch 31: Train Loss = 0.0004
# 2025-04-12 15:31:18,657 - INFO - Epoch 31 - Val MSE: 7.754444, RMSE: 2.784680, MAE: 2.080838, R²: 0.941527, MAPE: 2.136218%
# 2025/04/12 15:31:22 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:31:22,169 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:31:22,170 - INFO - Epoch 32, LR: 1.5625e-05
# 2025-04-12 15:31:25,123 - INFO - Epoch 32: Train Loss = 0.0004
# 2025-04-12 15:31:25,208 - INFO - Epoch 32 - Val MSE: 7.537549, RMSE: 2.745460, MAE: 2.066798, R²: 0.943163, MAPE: 2.121761%
# 2025/04/12 15:31:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:31:28,633 - INFO - Improved RMSE: 2.745460. Logged best model to MLflow.
# 2025/04/12 15:31:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:31:31,914 - INFO - Monitored metric improved to 2.745460
# 2025-04-12 15:31:31,914 - INFO - Epoch 33, LR: 1.5625e-05
# 2025-04-12 15:31:34,904 - INFO - Epoch 33: Train Loss = 0.0004
# 2025-04-12 15:31:34,991 - INFO - Epoch 33 - Val MSE: 7.619110, RMSE: 2.760273, MAE: 2.067974, R²: 0.942548, MAPE: 2.123131%
# 2025/04/12 15:31:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:31:38,404 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:31:38,405 - INFO - Epoch 34, LR: 1.5625e-05
# 2025-04-12 15:31:41,378 - INFO - Epoch 34: Train Loss = 0.0004
# 2025-04-12 15:31:41,465 - INFO - Epoch 34 - Val MSE: 7.674950, RMSE: 2.770370, MAE: 2.072710, R²: 0.942127, MAPE: 2.127894%
# 2025/04/12 15:31:44 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:31:44,845 - INFO - Monitored metric did not improve. Counter: 2/6
# 2025-04-12 15:31:44,845 - INFO - Epoch 35, LR: 1.5625e-05
# 2025-04-12 15:31:47,759 - INFO - Epoch 35: Train Loss = 0.0004
# 2025-04-12 15:31:47,843 - INFO - Epoch 35 - Val MSE: 7.515366, RMSE: 2.741417, MAE: 2.063822, R²: 0.943330, MAPE: 2.118438%
# 2025/04/12 15:31:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:31:51,220 - INFO - Improved RMSE: 2.741417. Logged best model to MLflow.
# 2025/04/12 15:31:54 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:31:54,445 - INFO - Monitored metric improved to 2.741417
# 2025-04-12 15:31:54,446 - INFO - Epoch 36, LR: 1.5625e-05
# 2025-04-12 15:31:57,296 - INFO - Epoch 36: Train Loss = 0.0004
# 2025-04-12 15:31:57,379 - INFO - Epoch 36 - Val MSE: 7.520278, RMSE: 2.742313, MAE: 2.060483, R²: 0.943293, MAPE: 2.115084%
# 2025/04/12 15:32:00 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:32:00,675 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:32:00,675 - INFO - Epoch 37, LR: 1.5625e-05
# 2025-04-12 15:32:03,573 - INFO - Epoch 37: Train Loss = 0.0003
# 2025-04-12 15:32:03,657 - INFO - Epoch 37 - Val MSE: 7.485185, RMSE: 2.735907, MAE: 2.057435, R²: 0.943558, MAPE: 2.111873%
# 2025/04/12 15:32:06 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:32:06,976 - INFO - Improved RMSE: 2.735907. Logged best model to MLflow.
# 2025/04/12 15:32:10 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:32:10,304 - INFO - Monitored metric improved to 2.735907
# 2025-04-12 15:32:10,304 - INFO - Epoch 38, LR: 1.5625e-05
# 2025-04-12 15:32:13,277 - INFO - Epoch 38: Train Loss = 0.0003
# 2025-04-12 15:32:13,366 - INFO - Epoch 38 - Val MSE: 7.540751, RMSE: 2.746043, MAE: 2.060091, R²: 0.943139, MAPE: 2.114724%
# 2025/04/12 15:32:17 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:32:17,046 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:32:17,046 - INFO - Epoch 39, LR: 1.5625e-05
# 2025-04-12 15:32:19,993 - INFO - Epoch 39: Train Loss = 0.0003
# 2025-04-12 15:32:20,080 - INFO - Epoch 39 - Val MSE: 7.464115, RMSE: 2.732053, MAE: 2.063092, R²: 0.943717, MAPE: 2.117207%
# 2025/04/12 15:32:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:32:23,530 - INFO - Improved RMSE: 2.732053. Logged best model to MLflow.
# 2025/04/12 15:32:26 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:32:26,876 - INFO - Monitored metric improved to 2.732053
# 2025-04-12 15:32:26,876 - INFO - Epoch 40, LR: 1.5625e-05
# 2025-04-12 15:32:29,811 - INFO - Epoch 40: Train Loss = 0.0003
# 2025-04-12 15:32:29,898 - INFO - Epoch 40 - Val MSE: 7.418999, RMSE: 2.723784, MAE: 2.050138, R²: 0.944057, MAPE: 2.104203%
# 2025/04/12 15:32:33 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:32:33,323 - INFO - Improved RMSE: 2.723784. Logged best model to MLflow.
# 2025/04/12 15:32:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:32:36,703 - INFO - Monitored metric improved to 2.723784
# 2025-04-12 15:32:36,703 - INFO - Epoch 41, LR: 1.5625e-05
# 2025-04-12 15:32:39,696 - INFO - Epoch 41: Train Loss = 0.0003
# 2025-04-12 15:32:39,783 - INFO - Epoch 41 - Val MSE: 7.442465, RMSE: 2.728088, MAE: 2.047528, R²: 0.943880, MAPE: 2.101627%
# 2025/04/12 15:32:43 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:32:43,221 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:32:43,221 - INFO - Epoch 42, LR: 1.5625e-05
# 2025-04-12 15:32:46,167 - INFO - Epoch 42: Train Loss = 0.0003
# 2025-04-12 15:32:46,253 - INFO - Epoch 42 - Val MSE: 7.349878, RMSE: 2.711066, MAE: 2.041039, R²: 0.944578, MAPE: 2.094872%
# 2025/04/12 15:32:49 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:32:49,608 - INFO - Improved RMSE: 2.711066. Logged best model to MLflow.
# 2025/04/12 15:32:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:32:52,903 - INFO - Monitored metric improved to 2.711066
# 2025-04-12 15:32:52,903 - INFO - Epoch 43, LR: 1.5625e-05
# 2025-04-12 15:32:55,915 - INFO - Epoch 43: Train Loss = 0.0003
# 2025-04-12 15:32:56,002 - INFO - Epoch 43 - Val MSE: 7.362769, RMSE: 2.713442, MAE: 2.049924, R²: 0.944481, MAPE: 2.103647%
# 2025/04/12 15:32:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:32:59,370 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:32:59,370 - INFO - Epoch 44, LR: 1.5625e-05
# 2025-04-12 15:33:02,328 - INFO - Epoch 44: Train Loss = 0.0004
# 2025-04-12 15:33:02,415 - INFO - Epoch 44 - Val MSE: 7.418595, RMSE: 2.723710, MAE: 2.040620, R²: 0.944060, MAPE: 2.094328%
# 2025/04/12 15:33:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:33:05,805 - INFO - Monitored metric did not improve. Counter: 2/6
# 2025-04-12 15:33:05,805 - INFO - Epoch 45, LR: 1.5625e-05
# 2025-04-12 15:33:08,771 - INFO - Epoch 45: Train Loss = 0.0003
# 2025-04-12 15:33:08,904 - INFO - Epoch 45 - Val MSE: 7.368432, RMSE: 2.714486, MAE: 2.037205, R²: 0.944438, MAPE: 2.090800%
# 2025/04/12 15:33:12 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:33:12,268 - INFO - Monitored metric did not improve. Counter: 3/6
# 2025-04-12 15:33:12,268 - INFO - Epoch 46, LR: 3.90625e-06
# 2025-04-12 15:33:15,232 - INFO - Epoch 46: Train Loss = 0.0003
# 2025-04-12 15:33:15,323 - INFO - Epoch 46 - Val MSE: 7.394629, RMSE: 2.719307, MAE: 2.038858, R²: 0.944241, MAPE: 2.092509%
# 2025/04/12 15:33:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:33:18,708 - INFO - Monitored metric did not improve. Counter: 4/6
# 2025-04-12 15:33:18,708 - INFO - Epoch 47, LR: 3.90625e-06
# 2025-04-12 15:33:21,657 - INFO - Epoch 47: Train Loss = 0.0003
# 2025-04-12 15:33:21,744 - INFO - Epoch 47 - Val MSE: 7.328823, RMSE: 2.707180, MAE: 2.032650, R²: 0.944737, MAPE: 2.086085%
# 2025/04/12 15:33:25 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:33:25,129 - INFO - Improved RMSE: 2.707180. Logged best model to MLflow.
# 2025/04/12 15:33:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:33:28,446 - INFO - Monitored metric improved to 2.707180
# 2025-04-12 15:33:28,446 - INFO - Epoch 48, LR: 3.90625e-06
# 2025-04-12 15:33:31,408 - INFO - Epoch 48: Train Loss = 0.0003
# 2025-04-12 15:33:31,494 - INFO - Epoch 48 - Val MSE: 7.292920, RMSE: 2.700541, MAE: 2.033694, R²: 0.945008, MAPE: 2.087060%
# 2025/04/12 15:33:34 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:33:34,834 - INFO - Improved RMSE: 2.700541. Logged best model to MLflow.
# 2025/04/12 15:33:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:33:38,160 - INFO - Monitored metric improved to 2.700541
# 2025-04-12 15:33:38,161 - INFO - Epoch 49, LR: 3.90625e-06
# 2025-04-12 15:33:41,164 - INFO - Epoch 49: Train Loss = 0.0003
# 2025-04-12 15:33:41,250 - INFO - Epoch 49 - Val MSE: 7.336848, RMSE: 2.708662, MAE: 2.035253, R²: 0.944676, MAPE: 2.088671%
# 2025/04/12 15:33:44 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:33:44,849 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:33:44,850 - INFO - Epoch 50, LR: 3.90625e-06
# 2025-04-12 15:33:47,840 - INFO - Epoch 50: Train Loss = 0.0003
# 2025-04-12 15:33:47,925 - INFO - Epoch 50 - Val MSE: 7.319046, RMSE: 2.705373, MAE: 2.030211, R²: 0.944811, MAPE: 2.083543%
# 2025/04/12 15:33:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:33:51,221 - INFO - Monitored metric did not improve. Counter: 2/6
# 2025-04-12 15:33:51,222 - INFO - Epoch 51, LR: 3.90625e-06
# 2025-04-12 15:33:54,080 - INFO - Epoch 51: Train Loss = 0.0003
# 2025-04-12 15:33:54,163 - INFO - Epoch 51 - Val MSE: 7.284539, RMSE: 2.698989, MAE: 2.029171, R²: 0.945071, MAPE: 2.082412%
# 2025/04/12 15:33:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:33:57,526 - INFO - Improved RMSE: 2.698989. Logged best model to MLflow.
# 2025/04/12 15:34:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:34:01,056 - INFO - Monitored metric improved to 2.698989
# 2025-04-12 15:34:01,057 - INFO - Epoch 52, LR: 3.90625e-06
# 2025-04-12 15:34:04,100 - INFO - Epoch 52: Train Loss = 0.0003
# 2025-04-12 15:34:04,189 - INFO - Epoch 52 - Val MSE: 7.288963, RMSE: 2.699808, MAE: 2.028687, R²: 0.945037, MAPE: 2.081912%
# 2025/04/12 15:34:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:34:07,621 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:34:07,622 - INFO - Epoch 53, LR: 3.90625e-06
# 2025-04-12 15:34:10,562 - INFO - Epoch 53: Train Loss = 0.0003
# 2025-04-12 15:34:10,651 - INFO - Epoch 53 - Val MSE: 7.304491, RMSE: 2.702682, MAE: 2.028759, R²: 0.944920, MAPE: 2.081996%
# 2025/04/12 15:34:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:34:14,067 - INFO - Monitored metric did not improve. Counter: 2/6
# 2025-04-12 15:34:14,068 - INFO - Epoch 54, LR: 3.90625e-06
# 2025-04-12 15:34:17,078 - INFO - Epoch 54: Train Loss = 0.0003
# 2025-04-12 15:34:17,168 - INFO - Epoch 54 - Val MSE: 7.338048, RMSE: 2.708883, MAE: 2.030821, R²: 0.944667, MAPE: 2.084098%
# 2025/04/12 15:34:20 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:34:20,531 - INFO - Monitored metric did not improve. Counter: 3/6
# 2025-04-12 15:34:20,532 - INFO - Epoch 55, LR: 1e-06
# 2025-04-12 15:34:23,511 - INFO - Epoch 55: Train Loss = 0.0003
# 2025-04-12 15:34:23,605 - INFO - Epoch 55 - Val MSE: 7.279915, RMSE: 2.698132, MAE: 2.027228, R²: 0.945106, MAPE: 2.080381%
# 2025/04/12 15:34:26 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:34:26,988 - INFO - Improved RMSE: 2.698132. Logged best model to MLflow.
# 2025/04/12 15:34:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:34:30,392 - INFO - Monitored metric improved to 2.698132
# 2025-04-12 15:34:30,392 - INFO - Epoch 56, LR: 1e-06
# 2025-04-12 15:34:33,418 - INFO - Epoch 56: Train Loss = 0.0003
# 2025-04-12 15:34:33,507 - INFO - Epoch 56 - Val MSE: 7.269399, RMSE: 2.696182, MAE: 2.027161, R²: 0.945185, MAPE: 2.080284%
# 2025/04/12 15:34:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:34:36,863 - INFO - Improved RMSE: 2.696182. Logged best model to MLflow.
# 2025/04/12 15:34:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:34:40,184 - INFO - Monitored metric improved to 2.696182
# 2025-04-12 15:34:40,184 - INFO - Epoch 57, LR: 1e-06
# 2025-04-12 15:34:43,177 - INFO - Epoch 57: Train Loss = 0.0003
# 2025-04-12 15:34:43,264 - INFO - Epoch 57 - Val MSE: 7.268750, RMSE: 2.696062, MAE: 2.027295, R²: 0.945190, MAPE: 2.080410%
# 2025/04/12 15:34:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:34:46,640 - INFO - Improved RMSE: 2.696062. Logged best model to MLflow.
# 2025/04/12 15:34:49 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:34:49,967 - INFO - Monitored metric improved to 2.696062
# 2025-04-12 15:34:49,968 - INFO - Epoch 58, LR: 1e-06
# 2025-04-12 15:34:52,953 - INFO - Epoch 58: Train Loss = 0.0003
# 2025-04-12 15:34:53,041 - INFO - Epoch 58 - Val MSE: 7.274616, RMSE: 2.697150, MAE: 2.026993, R²: 0.945146, MAPE: 2.080112%
# 2025/04/12 15:34:56 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:34:56,375 - INFO - Monitored metric did not improve. Counter: 1/6
# 2025-04-12 15:34:56,375 - INFO - Epoch 59, LR: 1e-06
# 2025-04-12 15:34:59,353 - INFO - Epoch 59: Train Loss = 0.0003
# 2025-04-12 15:34:59,441 - INFO - Epoch 59 - Val MSE: 7.276350, RMSE: 2.697471, MAE: 2.027219, R²: 0.945133, MAPE: 2.080338%
# 2025/04/12 15:35:02 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:35:02,874 - INFO - Monitored metric did not improve. Counter: 2/6
# 2025-04-12 15:35:02,874 - INFO - Epoch 60, LR: 1e-06
# 2025-04-12 15:35:05,875 - INFO - Epoch 60: Train Loss = 0.0003
# 2025-04-12 15:35:05,963 - INFO - Epoch 60 - Val MSE: 7.303944, RMSE: 2.702581, MAE: 2.028645, R²: 0.944925, MAPE: 2.081828%
# 2025/04/12 15:35:09 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:35:09,362 - INFO - Monitored metric did not improve. Counter: 3/6
# 2025-04-12 15:35:09,362 - INFO - Epoch 61, LR: 1e-06
# 2025-04-12 15:35:12,353 - INFO - Epoch 61: Train Loss = 0.0003
# 2025-04-12 15:35:12,441 - INFO - Epoch 61 - Val MSE: 7.293512, RMSE: 2.700650, MAE: 2.027944, R²: 0.945003, MAPE: 2.081097%
# 2025/04/12 15:35:15 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:35:15,806 - INFO - Monitored metric did not improve. Counter: 4/6
# 2025-04-12 15:35:15,807 - INFO - Epoch 62, LR: 1e-06
# 2025-04-12 15:35:18,856 - INFO - Epoch 62: Train Loss = 0.0003
# 2025-04-12 15:35:18,947 - INFO - Epoch 62 - Val MSE: 7.314121, RMSE: 2.704463, MAE: 2.029571, R²: 0.944848, MAPE: 2.082779%
# 2025/04/12 15:35:22 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:35:22,272 - INFO - Monitored metric did not improve. Counter: 5/6
# 2025-04-12 15:35:22,272 - INFO - Epoch 63, LR: 1e-06
# 2025-04-12 15:35:25,280 - INFO - Epoch 63: Train Loss = 0.0003
# 2025-04-12 15:35:25,371 - INFO - Epoch 63 - Val MSE: 7.295173, RMSE: 2.700958, MAE: 2.027988, R²: 0.944991, MAPE: 2.081129%
# 2025/04/12 15:35:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025-04-12 15:35:28,758 - INFO - Monitored metric did not improve. Counter: 6/6
# 2025-04-12 15:35:28,759 - WARNING - Early stopping triggered.
# 2025-04-12 15:35:28,764 - WARNING - Early stopping triggered. Stopping training.
# 2025-04-12 15:35:28,768 - INFO - Logged mlflow_run.log to MLflow
# 🏃 View run calm-crane-452 at: http://0.0.0.0:5001/#/experiments/635037021632314375/runs/8917a4866de84e728f325371df570b8e
# 🧪 View experiment at: http://0.0.0.0:5001/#/experiments/635037021632314375

# %%
# After loading your best model
model.eval()
all_preds = []
all_targets = []

with torch.no_grad():
    for sequences, targets in test_loader:
        sequences = sequences.to(device)
        outputs = model(sequences)
        all_preds.extend(outputs.cpu().numpy())
        all_targets.extend(targets.numpy())

# Inverse transform predictions and actual values
y_pred_normalized = np.array(all_preds).reshape(-1, 1)
y_true_normalized = np.array(all_targets).reshape(-1, 1)
y_pred = scaler.inverse_transform(y_pred_normalized).flatten()
y_true = scaler.inverse_transform(y_true_normalized).flatten()

# Plot with original scale values
plt.figure(figsize=(10, 6))
plt.plot(y_true, label='Actual Values', marker='o', linewidth=2)
plt.plot(y_pred, label='Predicted Values', marker='x', linewidth=2)
plt.title('Predicted vs Actual Stock Prices')
plt.xlabel('Index')
plt.ylabel('Stock Price (₹)')
plt.legend()
plt.grid(True)
plt.show()
